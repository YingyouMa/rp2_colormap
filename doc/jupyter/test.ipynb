# %% [markdown]
# # Math typography test
#
# This notebook tests the notation intended for the project.
#
# ## Vector styles
#
# Ordinary scalar: $n$
#
# Upright: $\mathrm{n}$
#
# Bold upright vector: $\mathbf{n}$
#
# Bold Greek: $\boldsymbol{\beta}$
#
# Matrix: $\mathbf{A}\in\mathbb{R}^{3\times3}$
#
# ## Blackboard bold and projective space
#
# $$\mathbb{R},\qquad \mathbb{S}^2,\qquad \mathbb{RP}^2$$
#
# $$\mathbf{n}\in\mathbb{S}^2,\qquad \mathbf{n}\sim-\mathbf{n},\qquad \mathbb{S}^2/\{\mathbf{n}\sim-\mathbf{n}\}\cong\mathbb{RP}^2.$$
#
# ## Calligraphic symbols, norms, maps, and differential geometry
#
# $$\mathbf{c}:\mathbb{RP}^2\longrightarrow\mathbb{R}^3$$
#
# $$\mathcal{J}_{\mathrm{pair}}=\iint_{\mathbb{RP}^2\times\mathbb{RP}^2}\left[\lVert\mathbf{c}([\mathbf{n}])-\mathbf{c}([\mathbf{m}])\rVert^2-\alpha\left(1-(\mathbf{n}\cdot\mathbf{m})^2\right)\right]^2\,\mathrm{d}\mu([\mathbf{n}])\,\mathrm{d}\mu([\mathbf{m}]).$$
#
# $$D\mathbf{c}_{[\mathbf{n}]}:T_{[\mathbf{n}]}\mathbb{RP}^2\longrightarrow T_{\mathbf{c}([\mathbf{n}])}\mathbb{R}^3,\qquad \operatorname{rank}\!\left(D\mathbf{c}_{[\mathbf{n}]}\right)=2.$$
#
# ## Stage-I notation
#
# $$\mathbf{c}_B([\mathbf{n}])=\mathbf{A}\,\mathbf{p}_B(\mathbf{n})+\boldsymbol{\beta}.$$

# %%
# Code cell included only to confirm this is a functional Jupyter notebook.
import sys
print(sys.version)
